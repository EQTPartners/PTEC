# %%
import os
import json
from sectors.experiments.embedding_proximity import (
    results_to_df,
    plot_method_model_size,
    plot_augmentation_model_size
)

paths = []
for root, dirs, files in os.walk("default"):
    for file in files:
        paths.append(os.path.join(root, file))

allresults = {}
for path in paths:
    with open(path, "r") as fp:
        allresults[path] = json.load(fp)

results = results_to_df(allresults)

# %%
plot_augmentation_model_size(results, "classification_head", "macro-f1")

# %%
plot_augmentation_model_size(results, "classification_head", "micro-f1")

# %%
plot_augmentation_model_size(results, "classification_head", "micro-jaccard")

# %%
plot_augmentation_model_size(results, "classification_head", "macro-jaccard")

# %%
plot_augmentation_model_size(results, "KNN", "macro-f1")

# %%
plot_augmentation_model_size(results, "KNN", "macro-jaccard")

# %%
plot_augmentation_model_size(results, "RN", "macro-f1")

# %%
plot_method_model_size(results, "preprocessed", "macro-f1")

# %%
plot_method_model_size(results, "augmented", "macro-f1")

# %%
plot_method_model_size(results, "augmented", "macro-jaccard")
